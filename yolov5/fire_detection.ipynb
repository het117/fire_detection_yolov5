# %%
# !pip install -r yolov5/requirements.txt

# %%
# 데이터셋 다운로드 후 data 폴더안에 압축풀기
# !unzip fire_yolov5.zip -d data/

# %%
# custom data train
# !python train.py --data "./data/custom.yaml" --epochs 10 --batch 16 --weights yolov5s.pt

# %%
# custom data detect / weights에는 pre_trained 모델 경로
# !python val.py --data "./data/custom.yaml" --weights "./runs/train/exp/weights/best.pt"

# %%
# custom data detect / source에는 이미지 파일 weights에는 pre_trained 모델 경로
# !python detect.py --weights "./runs/train/exp/weights/best.pt" --source "data/fire/train/images"
